# %%
from py_bref.franchises import Franchise

# %%
padres = Franchise("padres")
# Out:
# I'm 90% that you want San Diego Padres

# %% [markdown]
# things to test
#  * history
#  * batters
#  * pitchers
#  * draft
#  * parks

# %%
padres.hist("history")
# Out:
#                  Tm      Years     W     L   W-L%  Playoffs  Pnnts  WS
# 0  San Diego Padres  1969-2019  3747  4389  0.461         5      2   0

# %%
padres.batters().sort_values("G", ascending=False).head(23)
# Out:
#         Rk                Name  S  C  F  Yrs  From    To  ASG     G  ...   SB  \
# 359    353      Tony Gwynn HOF  S  C  F   20  1982  2001   15  2440  ...  319
# 924    907     Garry Templeton  -  -  -   10  1982  1991    1  1286  ...  101
# 1031  1012   Dave Winfield HOF  S  -  -    8  1973  1980    4  1117  ...  133
# 283    279        Tim Flannery  S  C  F   11  1979  1989    0   972  ...   22
# 776    762       Gene Richards  S  -  -    7  1977  1983    0   939  ...  242
# 385    379       Chase Headley  S  -  F    9  2007  2018    0   935  ...   73
# 971    953        Will Venable  S  -  -    8  2008  2015    0   918  ...  130
# 408    401  Trevor Hoffman HOF  -  -  -   16  1993  2008    6   878  ...    0
# 178    176        Nate Colbert  -  -  -    6  1969  1974    3   866  ...   48
# 474    466       Terry Kennedy  -  -  -    6  1981  1986    3   835  ...    3
# 322    317         Brian Giles  -  -  F    7  2003  2009    0   833  ...   43
# ...
