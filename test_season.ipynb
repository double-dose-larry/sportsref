# %%
from sportsref.baseball import Season
# Out:
# im calling bref now

# %%
season2019 = Season(2019)

# %%
bat2019 = season2019.standard_stats('players_standard_batting')
# Out:
# Available tables: ['teams_standard_batting', 'players_standard_batting']

# %%
bat2019.SO.sum()
# Out:
# 46324

# %%
bat19 = bat2019.query("Tm != 'TOT'")

# %%
bat19.groupby("Tm")[["H", "SO"]].sum().plot(kind="scatter", x="SO", y="H")

# %%
season2019_team = season2019.standard_stats("teams_standard_batting")
# Out:
# Available tables: ['teams_standard_batting', 'players_standard_batting']

# %%
import pandas as pd
pd.set_option("display.max_columns", 200)
import seaborn as sns
# Out:
# /home/jup/miniconda3/envs/jup/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(season2019_team.sort_values("GDP", ascending=True).corr(), ax=ax)

# %%
df = pd.DataFrame()
for yr in range(2010,2020):
    df[yr] =Season(yr).standard_stats('teams_standard_batting').set_index("Tm").SH.rank(ascending=False, method="dense")
# Out:
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']
# Available tables: ['teams_standard_batting', 'players_standard_batting']

# %%
df.sort_values(2019)
# Out:
#        2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# Tm
# LAD     1.0   7.0   1.0   3.0  12.0   7.0  16.0  12.0   6.0   1.0
# COL    11.0   6.0   3.0   6.0   6.0  11.0   3.0   1.0   3.0   2.0
# WSN     6.0   4.0  14.0   4.0   5.0   4.0   5.0   7.0   4.0   3.0
# PIT    10.0   6.0   9.0   7.0   9.0   3.0   9.0   8.0  11.0   4.0
# STL     8.0   3.0   6.0  10.0   4.0  14.0  11.0   6.0   2.0   5.0
# CLE    22.0  21.0  26.0  20.0  11.0   8.0  15.0  16.0  15.0   5.0
# SDP     2.0  13.0   8.0  12.0   8.0   6.0  12.0   3.0   8.0   6.0
# CHW    14.0  14.0  23.0  26.0  24.0  20.0  17.0  11.0  16.0   7.0
# PHI    16.0   9.0   5.0   9.0   6.0   5.0   6.0  17.0  10.0   8.0
# ARI    19.0  15.0  10.0  13.0   8.0   9.0   7.0   9.0   7.0   9.0
# CHC     9.0  11.0  17.0  16.0   7.0  19.0   8.0   5.0   5.0  10.0
# CIN     8.0   5.0   4.0   1.0   1.0   8.0   2.0   4.0   1.0  10.0
# NYM     5.0   9.0   7.0  11.0   6.0  21.0  13.0  10.0  13.0  11.0
# ...

# %%
bat2019.query("Tm == 'CLE' and SH > 0")
# Out:
#           Rk               Name   Age   Tm  Lg    G   PA   AB    R    H  2B  \
# 32      33.0        Greg Allen#  26.0  CLE  AL   89  256  231   30   53   9
# 118    119.0       Trevor Bauer  28.0  CLE  AL    2    6    5    0    1   0
# 446    447.0     Ryan Flaherty*  32.0  CLE  AL   14   22   21    4    3   2
# 471    472.0      Mike Freeman*  31.0  CLE  AL   75  213  177   27   49   8
# 760    761.0      Jason Kipnis*  32.0  CLE  AL  121  511  458   52  112  23
# 797    798.0  Francisco Lindor#  25.0  CLE  AL  143  654  598  101  170  40
# 862    863.0     Leonys Martin*  31.0  CLE  AL   65  264  236   32   47   7
# 920    921.0      Oscar Mercado  24.0  CLE  AL  115  482  438   70  118  25
# 956    957.0        Max Moroff#  26.0  CLE  AL   20   35   32    3    4   1
# 974    975.0      Tyler Naquin*  28.0  CLE  AL   89  294  274   34   79  19
# 1066  1067.0      Roberto Perez  30.0  CLE  AL  119  449  389   46   93   9
# ...

# %%
bat2019.query("H > 0").groupby("Tm").size().sort_values()
# Out:
# Tm
# MIN    20
# TEX    20
# BOS    22
# HOU    22
# BAL    23
# CHW    23
# DET    24
# NYY    24
# TOR    24
# OAK    25
# ATL    25
# KCR    26
# LAA    26
# SEA    26
# CLE    26
# STL    27
# TBR    28
# WSN    29
# PHI    30
# ARI    30
# COL    30
# CHC    30
# SDP    31
# MIL    31
# MIA    32
# NYM    32
# PIT    33
# LAD    33
# CIN    33
# SFG    38
# TOT    79
# dtype: int64
