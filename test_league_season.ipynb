# %%
from sportsref.baseball import League, Season

# %%
szn = Season(1985)

# %%
szn.batting("cumulative").get_df("players_cumulative_batting")
# Out:
# Available tables: ['players_cumulative_batting']
#         Rk             Name  Age  Yrs     G    PA    AB    R     H   2B  ...  \
# 0        1         Don Aase   30    8     0     0     0    0     0    0  ...
# 1        2    Johnny Abrego   22    1     6     9     9    0     0    0  ...
# 2        3        Jim Acker   26    3     0     0     0    0     0    0  ...
# 3        4      Ricky Adams   26    3   120   269   247   35    53    5  ...
# 4        5      Jim Adduci*   25    1    10    21    20    0     1    0  ...
# ...    ...              ...  ...  ...   ...   ...   ...  ...   ...  ...  ...
# 1020  1021  Joel Youngblood   33   10  1083  3499  3143  399   843  156  ...
# 1021  1022      Robin Yount   29   12  1671  7148  6515  961  1856  349  ...
# 1022  1023       Pat Zachry   33   10   293   367   318    9    36    0  ...
# 1023  1024      Geoff Zahn*   39   13    48    53    43    3     6    0  ...
# ...

# %%
szn.other('births').get_df('misc_pitching').query("Birthdate == 'Jan 18'")
# Out:
# Available tables: ['misc_batting', 'misc_pitching']
# Empty DataFrame
# Columns: [Rk, Name, Yrs, From, To, ASG, WAR, W, L, W-L%, ERA, G, GS, GF, CG, SHO, SV, IP, H, R, ER, HR, BB, IBB, SO, HBP, BK, WP, BF, WHIP, Birthdate, Birthplace, Tms]
# Index: []
#
# [0 rows x 33 columns]

# %%
szn.other('deaths').get_df('misc_manage')
# Out:
# Available tables: ['misc_batting', 'misc_pitching', 'misc_manage']
#    Rk                  Mgr  Yrs  From    To    W    L   W-L%  Ties  G>.500  \
# 0   1         Ossie Bluege    5  1943  1947  375  394  0.488     3     -19
# 1   2  Burleigh Grimes HOF    2  1937  1938  131  171  0.434     4     -40
# 2   3        Bob Scheffing    6  1957  1963  418  427  0.495     4      -9
#
#      G  BestFin  WrstFin  AvRk  Ejections Date of Death  \
# 0  772        2        8   4.6          4        Oct 14
# 1  306        6        7   6.5         15         Dec 6
# 2  849        2        8   5.1         10        Oct 26
#
#                             Died
# 0       Edina, MN, United States
# 1  Clear Lake, WI, United States
# 2     Phoenix, AZ, United States

# %%
szn.minor_leagues().get_df('league_pitching')
# Out:
# Available tables: ['league_batting', 'league_pitching', 'league_fielding', 'lg_history']
#       Rk                             Lg             Lev   Tms  PAge   R/G  \
# 0    1.0                American League    Major League  14.0  28.4  4.56
# 1    2.0                National League    Major League  12.0  28.2  4.07
# 2    NaN                            NaN             NaN   NaN   NaN   NaN
# 3    3.0           American Association             AAA   8.0  26.4  4.27
# 4    4.0           International League             AAA   8.0  25.9  4.24
# 5    5.0                 Mexican League             AAA  16.0   NaN  5.09
# 6    6.0           Pacific Coast League             AAA  10.0  25.7  4.67
# 7    NaN                            NaN             NaN   NaN   NaN   NaN
# 8    7.0                 Eastern League              AA   8.0  23.3  4.23
# 9    8.0                Southern League              AA  10.0  23.9  4.70
# ...
