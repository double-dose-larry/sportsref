# %%
from py_bref.franchises import Franchise

# %%
padres = Franchise("padres")
# Out:
# I'm 90% that you want San Diego Padres

# %% [markdown]
# things to test
#  * history
#  * batters
#  * pitchers
#  * draft
#  * parks

# %%
padres.hist("history")
# Out:
#                  Tm      Years     W     L   W-L%  Playoffs  Pnnts  WS
# 0  San Diego Padres  1969-2019  3747  4389  0.461         5      2   0

# %%
padres.batters().sort_values("G", ascending=False).head(23)
# Out:
#         Rk                Name  S  C  F  Yrs  From    To  ASG     G  ...   SB  \
# 359    353      Tony Gwynn HOF  S  C  F   20  1982  2001   15  2440  ...  319
# 924    907     Garry Templeton  -  -  -   10  1982  1991    1  1286  ...  101
# 1031  1012   Dave Winfield HOF  S  -  -    8  1973  1980    4  1117  ...  133
# 283    279        Tim Flannery  S  C  F   11  1979  1989    0   972  ...   22
# 776    762       Gene Richards  S  -  -    7  1977  1983    0   939  ...  242
# 385    379       Chase Headley  S  -  F    9  2007  2018    0   935  ...   73
# 971    953        Will Venable  S  -  -    8  2008  2015    0   918  ...  130
# 408    401  Trevor Hoffman HOF  -  -  -   16  1993  2008    6   878  ...    0
# 178    176        Nate Colbert  -  -  -    6  1969  1974    3   866  ...   48
# 474    466       Terry Kennedy  -  -  -    6  1981  1986    3   835  ...    3
# 322    317         Brian Giles  -  -  F    7  2003  2009    0   833  ...   43
# ...

# %%
padres.pitchers().sort_values("G", ascending=False).head(23)
# Out:
#       Rk                Name  S  C  F  Yrs  From    To  ASG    W  ...   ER  \
# 193  191  Trevor Hoffman HOF  -  -  -   16  1993  2008    6   54  ...  292
# 249  246      Craig Lefferts  -  -  -    7  1984  1992    0   42  ...  237
# 157  155      Luke Gregerson  S  -  -    5  2009  2013    0   17  ...  111
# 24    25          Heath Bell  -  -  -    5  2007  2011    3   27  ...  105
# 426  419           Eric Show  S  -  -   10  1981  1990    0  100  ...  639
# 253  250     Scott Linebrink  -  -  -    5  2003  2007    0   27  ...  103
# 466  458        Joe Thatcher  S  -  -    7  2007  2013    0    8  ...   70
# 128  127  Rollie Fingers HOF  -  -  -    4  1977  1980    1   34  ...  148
# 217  214         Randy Jones  S  -  -    8  1973  1980    2   92  ...  648
# 467  459         Dale Thayer  -  -  F    4  2012  2015    0   11  ...   80
# 474  466         Dave Tomlin  -  -  -    4  1974  1977    0   10  ...  115
# ...

# %%
print("https://widgets.sports-reference.com/wg.fcgi?css=1&site=br&url=%2Fdraft%2F%3Fteam_ID%3DSDP%26year_ID%3D2019%26draft_type%3Djunreg%26query_type%3Dfranch_year%26from_type_jc%3D0%26from_type_hs%3D0%26from_type_4y%3D0%26from_type_unk%3D0&div=div_draft_stats")
padres.draft(2017)
# Out:
# https://widgets.sports-reference.com/wg.fcgi?css=1&site=br&url=%2Fdraft%2F%3Fteam_ID%3DSDP%26year_ID%3D2019%26draft_type%3Djunreg%26query_type%3Dfranch_year%26from_type_jc%3D0%26from_type_hs%3D0%26from_type_4y%3D0%26from_type_unk%3D0&div=div_draft_stats
# https://widgets.sports-reference.com/wg.fcgi?css=1&site=br&url=%2Fdraft%2F%3Fteam_ID%3DSDP%26year_ID%3D2017%26draft_type%3Djunreg%26query_type%3Dfranch_year%26from_type_jc%3D0%26from_type_hs%3D0%26from_type_4y%3D0%26from_type_unk%3D0&div=div_draft_stats
#     Year  Rnd  DT  OvPck  RdPck      Tm Signed                         Name  \
# 0   2017    1 NaN      3      3  Padres      Y      MacKenzie Gore (minors)
# 1   2017    2 NaN     39      3  Padres      Y      Luis Campusano (minors)
# 2   2017    2 NaN     69     33  Padres      Y          Blake Hunt (minors)
# 3   2017    3 NaN     78      3  Padres      Y         Mason House (minors)
# 4   2017    4 NaN    108      3  Padres      Y         Sam Keating (minors)
# ...

# %%
padres.parks()
# Out:
#     Year                Tm       Lg   W    L  Finish        Playoffs  \
# 0   2019  San Diego Padres  NL West  70   92       5             NaN
# 1   2018  San Diego Padres  NL West  66   96       5             NaN
# 2   2017  San Diego Padres  NL West  71   91       4             NaN
# 3   2016  San Diego Padres  NL West  68   94       5             NaN
# 4   2015  San Diego Padres  NL West  74   88       4             NaN
# 5   2014  San Diego Padres  NL West  77   85       3             NaN
# 6   2013  San Diego Padres  NL West  76   86       3             NaN
# 7   2012  San Diego Padres  NL West  76   86       4             NaN
# 8   2011  San Diego Padres  NL West  71   91       5             NaN
# 9   2010  San Diego Padres  NL West  90   72       2             NaN
# 10  2009  San Diego Padres  NL West  75   87       4             NaN
# 11  2008  San Diego Padres  NL West  63   99       5             NaN
# 12  2007  San Diego Padres  NL West  89   74       3             NaN
# ...
