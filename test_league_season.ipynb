# %%
from sportsref.baseball import League, Season
# Out:
# im calling bref now

# %%
league = League()

# %%
league

# %%
league.wins()
# Out:
#      Year    G   ARI  ATL   BLA  BAL  BOS  CHC  CHW  CIN  ...  PHI  PIT   SDP  \
# 0    2019  162  85.0   97   NaN   54   84   84   72   75  ...   81   69  70.0
# 1    2018  163  82.0   90   NaN   47  108   95   62   67  ...   80   82  66.0
# 2    2017  162  93.0   72   NaN   75   93   92   67   68  ...   66   75  71.0
# 3    2016  162  69.0   68   NaN   89   93  103   78   68  ...   71   78  68.0
# 4    2015  162  79.0   67   NaN   81   78   97   76   64  ...   63   98  74.0
# ..    ...  ...   ...  ...   ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 118  1905  154   NaN   51   NaN   54   78   92   92   79  ...   83   96   NaN
# 119  1904  154   NaN   55   NaN   65   95   93   89   88  ...   52   87   NaN
# 120  1903  140   NaN   58   NaN   65   91   82   60   74  ...   49   91   NaN
# 121  1902  140   NaN   73  50.0   78   77   68   74   70  ...   56  103   NaN
# 122  1901  140   NaN   69  68.0   48   79   53   83   52  ...   83   90   NaN
#
# ...

# %%
league.stats(table="teams_standard_pitching", stats_type="pitch")
# Out:
#      Year  Tms   #P  PAge    R/G   ERA     G    GF    CG   SHO  ...     BF  \
# 0    2019   30  831  28.4   4.83  4.51  4858  0.99  0.01  0.01  ...  38.39
# 1    2018   30  799  28.4   4.45  4.15  4862  0.99  0.01  0.00  ...  38.08
# 2    2017   30  755  28.5   4.65  4.36  4860  0.99  0.01  0.01  ...  38.13
# 3    2016   30  742  28.3   4.48  4.19  4856  0.98  0.02  0.01  ...  38.01
# 4    2015   30  735  28.4   4.25  3.96  4858  0.98  0.02  0.01  ...  37.80
# ..    ...  ...  ...   ...    ...   ...   ...   ...   ...   ...  ...    ...
# 149  1875   13   42  24.3   6.14  2.23   690  0.10  0.90  0.07  ...  39.25
# 150  1874    8   17  24.7   7.48  2.19   464  0.05  0.95  0.03  ...  41.69
# 151  1873    9   25  21.3   8.99  3.40   398  0.09  0.91  0.02  ...  43.45
# 152  1872   11   21  21.1   9.26  3.66   366  0.11  0.89  0.03  ...  43.52
# 153  1871    9   19  24.6  10.47  4.22   254  0.09  0.91  0.02  ...  44.15
#
#      ERA+   WHIP  BAbip    H9  HR9  BB9  SO9  SO/W     E
# ...

# %%
mlb2019 = Season(2019)

# %%
mlb2019.standings("expanded_standings_overall")
# Out:
#       Rk     Tm   Lg      G    W    L   W-L% Strk    R   RA  ...   Road  \
# 0    1.0  y-HOU   AL  162.0  107   55  0.660  W 3  5.7  4.0  ...  47-34
# 1    2.0  y-LAD   NL  162.0  106   56  0.654  W 7  5.5  3.8  ...  47-34
# 2    3.0  y-NYY   AL  162.0  103   59  0.636  L 2  5.8  4.6  ...  46-35
# 3    4.0  y-MIN   AL  162.0  101   61  0.624  L 1  5.8  4.7  ...  55-26
# 4    5.0  y-ATL   NL  162.0   97   65  0.599  L 3  5.3  4.6  ...  47-34
# 5    6.0  w-OAK   AL  162.0   97   65  0.599  L 1  5.2  4.2  ...  45-36
# 6    7.0  w-TBR   AL  162.0   96   66  0.593  L 2  4.7  4.0  ...  48-33
# 7    8.0  w-WSN   NL  162.0   93   69  0.574  W 8  5.4  4.5  ...  43-38
# 8    9.0    CLE   AL  162.0   93   69  0.574  L 5  4.7  4.1  ...  44-37
# 9   10.0  y-STL   NL  162.0   91   71  0.562  W 1  4.7  4.1  ...  41-40
# 10  11.0  w-MIL   NL  162.0   89   73  0.549  L 3  4.7  4.7  ...  40-41
# 11  12.0    NYM   NL  162.0   86   76  0.531  W 3  4.9  4.5  ...  38-43
# ...

# %%
bat2019 = mlb2019.standard_stats('players_standard_batting')

# %%
bat2019.shape
# Out:
# (1555, 30)

# %%
bat2019
# Out:
#           Rk               Name   Age   Tm   Lg    G   PA   AB    R    H  ...  \
# 0        1.0     Fernando Abad*  33.0  SFG   NL   18    0    0    0    0  ...
# 1        2.0         Jose Abreu  32.0  CHW   AL  159  693  634   85  180  ...
# 2        3.0   Ronald Acuna Jr.  21.0  ATL   NL  156  715  626  127  175  ...
# 3        4.0         Jason Adam  27.0  TOR   AL    3    0    0    0    0  ...
# 4        5.0  Cristhian Adames#  27.0  SFG   NL   10   24   22    1    7  ...
# ...      ...                ...   ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1612  1551.0     Ryan Zimmerman  34.0  WSN   NL   52  190  171   20   44  ...
# 1613  1552.0  Jordan Zimmermann  33.0  DET   AL    1    2    2    0    0  ...
# 1614  1553.0       Ben Zobrist#  38.0  CHC   NL   47  176  150   24   39  ...
# 1615  1554.0        Mike Zunino  28.0  TBR   AL   90  289  266   30   44  ...
# 1616     NaN   LgAvg per 600 PA   NaN  NaN  NaN  201  600  536   75  134  ...
#
# ...

# %%
bat2019.query("PA > 100").sort_values("SLG", ascending=False).head(20).Tm.value_counts()
# Out:
# HOU    3
# LAD    2
# MIN    2
# PHI    2
# COL    2
# NYM    1
# CIN    1
# ARI    1
# CHC    1
# TEX    1
# SDP    1
# WSN    1
# MIL    1
# LAA    1
# Name: Tm, dtype: int64
