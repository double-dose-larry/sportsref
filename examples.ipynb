# %%
from sportsref.baseball import Player, Franchise, Season, League, Frivolities

# %%
import matplotlib.pyplot as plt
plt.xkcd()

# %% [markdown]
# # Get the strike outs from 1918

# %%
season1918 = Season(1918)

# %%
[ x for x in dir(season1918) if '__' not in x ]
# Out:
# ['batting_pages',
#  'fielding_pages',
#  'league',
#  'managers',
#  'minor_leagues',
#  'other_pages',
#  'overview',
#  'pitching_pages',
#  'standings',
#  'year']

# %%
season1918.pitching_pages('standard')
# Out:
# Available tables: ['teams_standard_pitching', 'players_standard_pitching']
# < Page, web_url : 'https://www.baseball-reference.com/leagues/MLB/1918-standard-pitching.shtml' >

# %%
season1918.pitching_pages('standard').get_df('teams_standard_pitching').set_index("Tm").SO.plot(figsize=(10,10), kind="bar")
# Out:
# Available tables: ['teams_standard_pitching', 'players_standard_pitching']

# %% [markdown]
# # Wade Boggs 1987 rolling 10 game batting average

# %%
boggs = Player("boggs")
# Out:
# I'm 90% sure that you want Wade Boggs

# %%
boggs_gamelog_page = boggs.game_logs_pages(1987, 'b')
# Out:
# Available tables: ['batting_gamelogs']

# %%
boggs_87_logs = boggs_gamelog_page.get_df('batting_gamelogs')

# %%
boggs_87_logs.head()
# Out:
#    Rk  Gcar Gtm    Date   Tm Unnamed: 5  Opp     Rslt Inngs  PA  ...    OBP  \
# 0   1   726   1   Apr 6  BOS          @  MIL    L,1-5    CG   4  ...  0.250
# 1   2   727   2   Apr 8  BOS          @  MIL    L,2-3    CG   4  ...  0.250
# 2   3   728   3   Apr 9  BOS          @  MIL  L,11-12    CG   5  ...  0.462
# 3   4   729   4  Apr 10  BOS        NaN  TOR    W,3-0    CG   4  ...  0.412
# 4   5   730   5  Apr 11  BOS        NaN  TOR   L,1-11    CG   4  ...  0.381
#
#      SLG    OPS  BOP   aLI    WPA  acLI    cWPA  RE24  Pos
# 0  0.250  0.500    1  0.63 -0.009  0.91  -0.01% -0.17   3B
# 1  0.143  0.393    1  1.27 -0.090  1.64  -0.07% -0.59   3B
# 2  0.600  1.062    1  1.15  0.148  1.40   0.11%  2.20   3B
# 3  0.571  0.983    1  0.46 -0.023  0.51  -0.02% -0.33   3B
# 4  0.556  0.937    1  0.65 -0.079  0.72  -0.05% -0.42   3B
#
# [5 rows x 38 columns]

# %%
boggs_87_logs.set_index("Rk").BA.rolling(10).mean().plot(figsize=(20,10))

# %% [markdown]
# # 2017 batting ratios

# %%
szn17 = Season(2017)

# %%
ratio = szn17.batting_pages("ratio")
# Out:
# Available tables: ['teams_ratio_batting', 'players_ratio_batting']

# %%
ratio.get_df('teams_ratio_batting')
# Out:
#        Tm   R/G   HR%    SO%    BB%  XBH% X/H%  SO/W  AB/SO  AB/HR  AB/RBI  \
# 0     ARI  5.01  3.5%  23.4%   9.3%  9.2%  41%  2.52    3.8   25.1     7.1
# 1     ATL  4.52  2.7%  19.1%   7.6%  7.7%  33%  2.50    4.7   33.8     7.9
# 2     BAL  4.59  3.8%  23.0%   6.4%  8.4%  35%  3.60    4.0   24.4     7.9
# 3     BOS  4.85  2.7%  19.3%   9.0%  7.7%  34%  2.14    4.6   33.7     7.7
# 4     CHC  5.07  3.6%  22.3%   9.9%  8.4%  38%  2.25    3.9   24.6     7.0
# 5     CHW  4.36  3.1%  23.1%   6.6%  7.9%  34%  3.48    3.9   29.6     8.2
# 6     CIN  4.65  3.5%  21.4%   9.1%  8.1%  36%  2.35    4.1   25.0     7.7
# 7     CLE  5.05  3.4%  18.5%   9.7%  9.2%  40%  1.91    4.8   26.0     7.1
# 8     COL  5.09  3.1%  22.7%   8.4%  8.4%  35%  2.71    3.9   28.8     7.0
# 9     DET  4.54  3.0%  21.4%   8.2%  8.3%  36%  2.61    4.2   29.7     7.9
# 10    HOU  5.53  3.8%  17.3%   8.1%  9.6%  38%  2.14    5.2   23.6     6.6
# 11    KCR  4.33  3.2%  19.4%   6.5%  7.9%  33%  2.99    4.7   28.7     8.4
# 12    LAA  4.38  3.1%  19.7%   8.6%  7.4%  34%  2.29    4.5   29.1     8.0
# 13    LAD  4.75  3.6%  22.3%  10.5%  8.9%  41%  2.13    3.9   24.5     7.4
# 14    MIA  4.80  3.1%  20.5%   7.8%  7.9%  33%  2.64    4.4   28.9     7.5
# 15    MIL  4.52  3.7%  25.6%   8.9%  8.4%  38%  2.87    3.5   24.4     7.9
# 16    MIN  5.03  3.3%  21.4%   9.5%  8.4%  36%  2.26    4.1   27.0     7.1
# 17    NYM  4.54  3.6%  20.9%   8.6%  8.7%  39%  2.44    4.3   24.6     7.7
# 18    NYY  5.30  3.8%  21.8%   9.7%  8.3%  36%  2.25    4.0   23.2     6.8
# 19    OAK  4.56  3.8%  24.3%   9.2%  9.0%  41%  2.64    3.7   23.4     7.7
# 20    PHI  4.26  2.8%  23.1%   8.1%  8.1%  36%  2.87    3.9   31.8     8.5
# 21    PIT  4.12  2.5%  19.8%   8.5%  7.1%  33%  2.34    4.5   36.1     8.6
# 22    SDP  3.73  3.2%  25.2%   7.7%  7.5%  36%  3.26    3.6   28.3     9.3
# 23    SEA  4.63  3.2%  20.6%   7.9%  8.1%  35%  2.60    4.4   27.8     7.8
# 24    SFG  3.94  2.1%  19.6%   7.6%  7.3%  32%  2.58    4.6   43.4     9.1
# 25    STL  4.70  3.2%  21.7%   9.5%  8.2%  36%  2.27    4.1   27.9     7.5
# 26    TBR  4.28  3.7%  25.0%   8.9%  7.9%  36%  2.82    3.6   24.0     8.2
# 27    TEX  4.93  3.9%  24.4%   8.9%  8.4%  39%  2.74    3.6   22.9     7.2
# 28    TOR  4.28  3.6%  21.6%   8.8%  8.1%  38%  2.45    4.1   24.8     8.3
# 29    WSN  5.06  3.5%  21.4%   8.7%  9.0%  38%  2.45    4.2   25.8     7.0
# 30  LgAvg  4.65  3.3%  21.6%   8.5%  8.3%  36%  2.53    4.1   27.1     7.7
#
#     GB/FB  GO/AO  IP%  LD%  HR/FB IF/FB
# 0    0.84   1.15  62%  26%  11.1%   11%
# 1    0.90   1.31  69%  25%   7.8%    9%
# 2    0.79   1.05  66%  26%  11.2%   12%
# 3    0.84   1.09  68%  25%   8.0%   13%
# 4    0.84   1.23  62%  25%  11.3%   11%
# 5    0.91   1.18  65%  24%   9.8%   12%
# 6    0.76   1.10  64%  25%  10.6%   12%
# 7    0.77   1.04  67%  25%   9.7%   12%
# 8    0.87   1.29  64%  26%   9.6%   10%
# 9    0.75   1.00  66%  28%   8.6%   10%
# 10   0.79   1.02  69%  25%  10.7%   13%
# 11   0.71   0.98  70%  28%   8.6%   12%
# 12   0.88   1.18  67%  23%   9.4%   12%
# 13   0.77   1.05  62%  25%  10.7%   10%
# 14   1.00   1.39  67%  24%  10.1%   11%
# 15   0.86   1.23  60%  25%  11.9%   10%
# 16   0.73   0.98  65%  26%   9.7%   12%
# 17   0.69   0.91  65%  25%  10.3%   13%
# 18   0.77   1.01  63%  25%  11.5%   13%
# 19   0.63   0.84  62%  27%  10.8%   12%
# 20   0.86   1.16  65%  25%   8.9%   11%
# 21   0.90   1.23  67%  25%   7.6%   10%
# 22   0.77   1.00  62%  24%  10.3%   15%
# 23   0.80   1.03  67%  25%   9.6%   12%
# 24   0.90   1.17  70%  24%   6.3%   12%
# 25   0.77   1.08  64%  26%   9.5%   11%
# 26   0.78   1.02  61%  24%  11.8%   13%
# 27   0.78   1.04  61%  24%  12.2%   13%
# 28   0.79   1.09  65%  24%  11.0%   13%
# 29   0.79   1.05  65%  25%  10.1%   10%
# 30   0.81   1.09  65%  25%   9.9%   12%

# %% [markdown]
# # 2018 Arizona Diamondbacks walk off losses

# %%
azn2018 = Franchise('dbacks').season(2018)

# %%
game_logs = azn2018.schedule_results()
# Out:
# Available tables: ['results', 'team_schedule']

# %%
game_logs.get_df('team_schedule').rename({"W/L" : 'WL'}, axis=1).query("WL == 'L-wo'")
# Out:
#      Gm#               Date Unnamed: 2   Tm Unnamed: 4  Opp    WL  R  RA  \
# 10    11    Tuesday, Apr 10   boxscore  ARI          @  SFG  L-wo  4   5
# 44    45   Saturday, May 19   boxscore  ARI          @  NYM  L-wo  4   5
# 60    61   Wednesday, Jun 6   boxscore  ARI          @  SFG  L-wo  4   5
# 103  104   Thursday, Jul 26   boxscore  ARI          @  CHC  L-wo  6   7
# 123  124   Saturday, Aug 18   boxscore  ARI          @  SDP  L-wo  6   7
# 131  132    Tuesday, Aug 28   boxscore  ARI          @  SFG  L-wo  0   1
# 136  137      Sunday, Sep 2   boxscore  ARI          @  LAD  L-wo  2   3
# 145  146  Wednesday, Sep 12   boxscore  ARI          @  COL  L-wo  4   5
# 159  160     Friday, Sep 28   boxscore  ARI          @  SDP  L-wo  2   3
# 161  162     Sunday, Sep 30   boxscore  ARI          @  SDP  L-wo  3   4
#
#       Inn  ...      GB         Win        Loss Save  Time D/N Attendance  \
# 10    NaN  ...  up 2.5  Strickland  De La Rosa  NaN  3:24   N      37869
# 44    NaN  ...  up 0.5     Familia      Chafin  NaN  3:04   N      39515
# 60   10.0  ...    Tied  Strickland      Chafin  NaN  3:38   D      41042
# 103   NaN  ...     1.5      Butler   Boxberger  NaN  3:22   D      38979
# 123   NaN  ...  up 0.5     Stammen      Chafin  NaN  2:54   N      24440
# 131   NaN  ...    Tied       Smith     Ziegler  NaN  3:03   N      37276
# 136   NaN  ...     1.0      Jansen   Boxberger  NaN  3:35   D      48517
# 145   NaN  ...     3.5       Davis      Hirano  NaN  3:07   N      31687
# 159  15.0  ...     9.0      Brewer    Andriese  NaN  5:02   N      28055
# 161  10.0  ...     9.0    Castillo     Barrett  NaN  3:29   D      31243
#
#       cLI  Streak  Orig. Scheduled
# 10   1.40       -              NaN
# 44   1.27     ---              NaN
# 60   1.53       -              NaN
# 103  1.74      --              NaN
# 123  2.03       -              NaN
# 131  2.28      --              NaN
# 136  3.38     ---              NaN
# 145  2.84       -              NaN
# 159  0.00       -              NaN
# 161  0.00       -              NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# # an All Tampa-born team

# %%
from sportsref.baseball import Frivolities, Player

# %%
bio_state = Frivolities().bio_state("FL")
# Out:
# Available tables: ['bio_batting', 'bio_pitching', 'bio_manage']

# %%
bats = bio_state.get_df("bio_batting")

# %%
current_bats = bats.query("To == 2019").sort_values("OPS", ascending=False)

# %%
current_bats[current_bats.Birthplace == "Tampa"].head(50)
# Out:
#       Rk          Name  Yrs  From    To  ASG    G  PA  AB    R  ...   SO  \
# 125  126  Taylor Davis    3  2017  2019    0   20  39  36  3.0  ...  9.0
# 147  148     Sam Dyson    8  2012  2019    0  238   2   2  0.0  ...  0.0
#
#         BA    OBP    SLG   OPS   WAR     Birthdate        Debut  Birthplace  \
# 125  0.222  0.256  0.333  0.59 -0.18  Nov 28, 1989  Sep 8, 2017       Tampa
# 147  0.000  0.000  0.000  0.00  5.54   May 7, 1988  Jul 5, 2012       Tampa
#
#         Pos
# 125  /2H351
# 147      *1
#
# [2 rows x 28 columns]

# %% [markdown]
# # Pro Football Reference

# %% [markdown]
# # Eli Manning Touchdown passes by game in Career

# %%
from sportsref.football import Player as football_player

# %%
eli = football_player("Eli manning")
# Out:
# I'm 100% sure that you want Eli Manning

# %%
eli2013 = eli.gamelogs_pages('career')
# Out:
# Available tables: ['stats', 'stats_playoffs']

# %%
eli2013.get_df('stats')["Passing"]["TD"].plot(figsize=(20,10), kind="bar", xticks=range(0,250, 30))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-f7142f5b92fe> in <module>
# ----> 1 eli2013.get_df('stats')["Passing"]["TD"].plot(figsize=(20,10), kind="bar", xticks=range(0,250, 30))
#
# ~/juplab/llwin/baseball_util/sportsref/sportsref/page.py in get_df(self, table)
#      89     def get_df(self, table):
#      90         tbl = self._cached_tables[table]
# ---> 91         return pd.read_html(str(tbl))[0]
#      92
#      93
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     914
#     915     ret = []
# --> 916     for table in tables:
#     917         try:
#     918             ret.append(_data_to_frame(data=table, **kwargs))
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/html.py in <genexpr>(.0)
#     212         """
#     213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
# --> 214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#     216     def _attr_getter(self, obj, attr):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse_thead_tbody_tfoot(self, table_html)
#     411
#     412         header = self._expand_colspan_rowspan(header_rows)
# --> 413         body = self._expand_colspan_rowspan(body_rows)
#     414         footer = self._expand_colspan_rowspan(footer_rows)
#     415
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/html.py in _expand_colspan_rowspan(self, rows)
#     457                 text = _remove_whitespace(self._text_getter(td))
#     458                 rowspan = int(self._attr_getter(td, "rowspan") or 1)
# --> 459                 colspan = int(self._attr_getter(td, "colspan") or 1)
#     460
#     461                 for _ in range(colspan):
#
# ValueError: invalid literal for int() with base 10: "\\'30\\'"

# %% [markdown]
# # Keyshawn Johnson Yards per reception on the road from 2001

# %%
keyshawn = football_player("keyshawn")

# %%
key_2001_splits = keyshawn.splits_pages(2001).get_df('stats')

# %%
key_2001_splits.loc[:,key_2001_splits.columns.get_level_values(1)=="Split"] = key_2001_splits.loc[:,key_2001_splits.columns.get_level_values(1)=="Split"].ffill()

# %%
road_split = key_2001_splits.loc[key_2001_splits["Unnamed: 1_level_0"]["Value"] == 'Road']

# %%
road_split["Receiving"]["Y/R"].iloc[0]

# %% [markdown]
# # Derrick Henry's longest run form 2018

# %%
d = football_player("derrk henry")

# %%
d_plays = d.plays_pages(2018, 'rushing').get_df('all_plays')

# %%
d_plays.loc[d_plays.Yds.idxmax(), "Detail"]

# %% [markdown]
# # Suh's Penalites

# %%
suh = football_player("suh")

# %%
suh_penalites = suh.more_pages("penalties")

# %%
suh_penalites.get_df("penalties")\
    .assign(dt=lambda x: pd.to_datetime(x.Date).dt.year)\
    .groupby(["dt", "Penalty"]).Yds.sum().unstack()\
    .fillna(0)\
    .plot(kind='bar', stacked=True, figsize=(20,10), cmap="tab20")

# %%
from sportsref.football import Franchise as football_fran

# %%
nwe = football_fran("patriots")
